# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 1 invul template

# %% [markdown]
# ## Groepsgegevens en planning
#
# Aan het einde van deze ontwerpopdracht lever je als groep dit notebook gezamenlijk in via een pull request op Github en lever je een link naar dit pull request in op Brightspace. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan. Werk in de juiste branch.
#
# | Groep: 21     |  |
# | :-------------|:-------------|
# | George de jong| 6468845 |
# | Moos Stoop| 6525474 |
# | Wobbe van der Woude| 6581099 |
#
# | Planning Groep: 21     |Tijdstip / Tijdspanne  |
# |---|---|
# | Mijlpaal 1: Criteria opgesteld | 11:45 |
# | Mijlpaal 2: Eerste kalibratie meting gedaan| 15:00|
# | Pauze 1| 12:30-13:30 |

# %% [markdown]
# ## *Opdracht 1*: Foto van alle schetsen.
#
# Zet de foto in dezelfde map als dit notebook en verander hieronder de naam in de naam van de foto.
#
# ![Alt](Ontwerpen_sensoren.jpg "analyse: ideeen")

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |Krachtsensor | weegschaal voor kleine objecten | Moet kunnen wegen tussen de 0 en 500g bij een g van 9,81. Strevend naar een meetonzekerheid van +/- 3 gram zodat je boter zo ongeveer genoeg is voor je cake bijvoorbeeld. De sensor moet het een paar jaar kunnen doen zodat je lekker kan koken.|
# |temperatuur | waterkoker | Moet tegen water van 100 graden celsius kunnen en 100 graden celsius kunnen meten en dan een signaal geven. Een meetonzekerheid van +/- 0.1 graden celsius is wenselijk. Het liefst overleeft ie 10 jaar zodat de waterkoker het 10 jaar lang kan doen.|
# |licht| Wanneer is het dag en nacht | Moet zonlicht kunnen meten en tegen weerstomstandigheden kunnen. De sensor moet tussen 500 en 10000 lux meten. Hij moet 24/7 aan kunnen staan. Strevend naar een meetonzekerheid van +/- 100 lux.|
#
# Groep 21 heeft gekozen voor de kracht sensor.

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
# Hierbij onze opstelling. Hierin is de arduino te zien die de signalen van de sensor opvangt. Op de breadboard is een spanningsdeler gemaakt met een weerstand en de krachtsensor. De sensor zit helemaal aan de rand van het board, zodat er iets op gelegd kan worden, zoals een blokje boter. Dit is ook op de tekening te zien is. Ter verduidelijking onderaan een schematische tekening van de breadboard geschakeld aan de arduino. De arduino zit vast aan de computer die de signalen opvangt.
#  ![Alt](opstelling.jpg "schets student")

# %% [markdown]
# ## *Opdracht 4*: Beantwoord de vragen
#
# 1. Welke variabelen ga je veranderen?
# 2. Over welk bereik ga je deze variabelen veranderen?
# 3. Wat ga je allemaal meten?
# 4. Hoeveel metingen ga je doen?
# 5. Ga je met deze keuzes kunnen evalueren of jouw sensor geschikt is voor de gekozen toepassingen?
#
#
# Antwoorden:
# 1. de massa (m) die op de sensor drukt.
# 2. van 0g tot 500g.
# 3. gewogen gewichtjes op een al bestaande weegscheel, waarvan de massa al bekend is om te kunnen eiken.
# 4. in stapjes van 50g dus 10 stappen in totaal. elke stap 5 metingen, waarvan we het gemiddelde pakken. Dan weten we de max en min en daarme de onzekerheid.
# 5. ja, want met deze keuzes heb je uiteindelijk een gekalibreerde druksensor die over bepaalde massa kan meten van 0 tot 500g. Dit valt onder de gekozen criteria van 0 tot 500 gram van de weegschaal en ook de bepaalde meetonzekerheid.
#
#
# meetplan
# kalibreren de opstelling met gewogen hout stukjes
# daarna doen wij de gewogen hout stukjes er een voor een op zodat we het gewicht langzaam verhogen  per gewicht doen we vijf metingen en daar nemen wij het gemiddelde van en de waardes van opschrijven deze waardes verwerken in python om zo een fit lijn te krijgen

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Licht kort toe wat er in de foto te zien is.
#  ![Alt](TU_P2_rgb.png "meetopstelling student")

# %% [markdown]
# ## *Opdracht 6*: Meten en fitten, Leerdoel

# %%
#import necessary libraries
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit 
# Zet hier jouw data in een voor jou handig formaat

m_sensor1 = np.array([108,104,107,106,106])
m_sensor2 = np.array([243,243,241,238,238])
m_sensor3 = np.array([378,377,377,378,378])
m_sensor4 = np.array([480,484,484,486,485])
m_sensor5 = np.array([558,559,560,554,558])
m_sensor6 = np.array([651,654,654,656,657])
m_sensor7 = np.array([8,8,6,7,12])
m_sensor8 = np.array([146,143,134,136,137])
m_sensor9 = np.array([427,426,419,427,429])
m_sensor10 = np.array([481,487,484,489,469])

m_sensor = np.array([np.mean(m_sensor1),np.mean(m_sensor2),np.mean(m_sensor3),np.mean(m_sensor4),np.mean(m_sensor5),np.mean(m_sensor6),np.mean(m_sensor7),np.mean(m_sensor8),np.mean(m_sensor9),np.mean(m_sensor10)])
std_sensor = np.array([np.std(m_sensor1),np.std(m_sensor2),np.std(m_sensor3),np.std(m_sensor4),np.std(m_sensor5),np.std(m_sensor6),np.std(m_sensor7),np.std(m_sensor8),np.std(m_sensor9),np.std(m_sensor10)])
u_sensor = std_sensor / np.sqrt(5)


m_gewogen = np.array([103.7, 176.2, 267.8, 319.4, 389.4, 576.4, 72.5, 161.2, 231.2, 281.8  ])
u_gewogen = 0.1

# %%
# Plot hier de meting en fit een lijn door de metingen.
# Maak gebruik van wat je geleerd hebt bij het practicum.

def fitfunctie(x,a,b):
    return a*x + b

popt, pcov = curve_fit(fitfunctie, m_gewogen, m_sensor)


x = np.linspace(0,600,1000)
y = fitfunctie(x, *popt)

plt.figure()
plt.errorbar(m_gewogen, m_sensor, u_gewogen, u_sensor, "o", label="data")
plt.plot(x,y,"r--", label="fitfunctie")
plt.xlabel('daadwerkelijk gewicht (g)')
plt.ylabel('meetwaardes van de sensor')
plt.xlim(0,600)
plt.ylim(0,700) 
plt.legend()
plt.show()

# %% [markdown]
# ## *Opdracht 7*: Iteratie nodig?

# %% [markdown]
# Vervang deze tekst door jouw antwoord.

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
#
# Vervang deze tekst door jouw conclusie.

# %% [markdown]
# ## *Opdracht 9*: Aantonen leerdoelen beheersing
#
# Om aan te tonen dat je de leerdoelen beheerst, kopieer je hieronder alle cellen met 'leerdoel' in de titel. Zet zelf de cellen onder de goede kopjes. Mogelijk komt een cel bij meerdere leerdoelen terug.

# %% [markdown]
# ### Leerdoel 1: Simpele circuits (RC-circuit, spanningsdelers met sensoren) ontwerpen en fabriceren.

# %% [markdown]
# Kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 1 beheersen.

# %% [markdown]
# ### Leerdoel 2: Ontwerpeisen voor een opdracht SMART opstellen en vervolgens de ontwerpcyclus inrichten, rekening houdend met de randvoorwaarde van de opdracht.

# %% [markdown]
# Kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 2 beheersen.

# %% [markdown]
# ### Leerdoel 3: Voor een gegeven sensor & analoog-digitaal convertor en gegeven (of zelf gekozen) toepassing een kalibratie meting ontwerpen, inclusief het circuit om de sensor aan te sluiten op de analoog-digitaal convertor, de opstelling bouwen, en meetresultaten verwerken en concluderen of de combinatie van sensor en analoog-digitaal conversie geschikt is voor de toepassing.

# %% [markdown]
# Kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 3 beheersen.
